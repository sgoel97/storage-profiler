# %% [markdown]
# # System Storage Profiler

# %%
from utils import get_current_path, get_files

# %%
get_current_path()
# Out:
# 'Currently at /Users/samarthgoel/Desktop/storage-profiler'

# %%
get_files("./")
# Out:
# Gathering data from /Users/samarthgoel/Desktop/storage-profiler
#     size_gb                          dirpath  \
# 0     0.256                                .
# 1     0.384                           ./.git
# 2     0.192                   ./.git/objects
# 3     0.096                ./.git/objects/3c
# 4     0.096                ./.git/objects/fb
# 5     0.128              ./.git/objects/pack
# 6     0.064              ./.git/objects/info
# 7     0.096                      ./.git/info
# 8     0.128                      ./.git/logs
# 9     0.128                 ./.git/logs/refs
# 10    0.096           ./.git/logs/refs/heads
# 11    0.096         ./.git/logs/refs/remotes
# 12    0.096  ./.git/logs/refs/remotes/origin
# 13    0.480                     ./.git/hooks
# 14    0.160                      ./.git/refs
# 15    0.096                ./.git/refs/heads
# 16    0.064                 ./.git/refs/tags
# 17    0.096              ./.git/refs/remotes
# ...
